# %% [markdown]
# ![Heart Disease](https://qph.fs.quoracdn.net/main-qimg-c3bebbfabf55aa367c60e24cb0eb8c08)

# %% [markdown]
# ## Request :- For better experience of Data Visualization, please do have a look at my Kaggle Notebook [here](https://www.kaggle.com/kartik2khandelwal/some-questions-related-to-heart-disease-answered)
# <hr style="border:2px solid black"> </hr>

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../input/heart-failure-prediction/heart.csv')
data = df[df['HeartDisease'] == 1]
data.head(2)

# %% [markdown]
# # Questions with Answers
# <hr style="border:1px solid black"> </hr>
# <hr style="border:1px solid black"> </hr>

# %% [markdown]
# ## Q1 - Are Males more prone to Heart failure ?

# %%
fig1 = px.bar(data['Sex'].value_counts(), height=400, width=800, orientation='h',
       title='Heart Failure on the basis of Gender', 
       labels = {'value':'Count', 'index':'Gender'})
fig2 = px.pie(data, names='Sex', hole=0.5, height=480, width=800, 
             labels={'M':'Male', 'F':'Female'},
             title='Count of Gender')
fig1.show()
fig2.show()

# %% [markdown]
# ![](https://storage.googleapis.com/kagglesdsdata/datasets/1821434/2971219/newplot.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20211226%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20211226T114445Z&X-Goog-Expires=345599&X-Goog-SignedHeaders=host&X-Goog-Signature=...)
#
# ![](https://storage.googleapis.com/kagglesdsdata/datasets/1821434/2971219/newplot%20%281%29.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20211226%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20211226T114704Z&X-Goog-Expires=345599&X-Goog-SignedHeaders=host&X-Goog-Signature=...)

# %% [markdown]
# <hr style="border:1px solid black"> </hr>
# <h3> Ans 1 - Clearly, Males have almost 10x more heart failures compared to Females.
# <hr style="border:1px solid black"> </hr>

# %% [markdown]
# ## Q2 - Which Age group is more prone to Heart Failure ?

# %%
data['Age_group'] = pd.cut(x=data['Age'], bins=[30, 40, 50, 60, 70, 80],
                            labels=['30 to 40', '40 to 50', '50 to 60', '60 to 70', '70 to 80'])

# %%
px.bar(data['Age_group'].value_counts(), height=400, width=800, orientation='v',
       title='Heart Failure on the basis of Age',
      labels = {'value':'Count', 'index':'Age'})

# %% [markdown]
# ![](https://storage.googleapis.com/kagglesdsdata/datasets/1821434/2971219/newplot%20%282%29.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20211226%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20211226T114847Z&X-Goog-Expires=345599&X-Goog-SignedHeaders=host&X-Goog-Signature=...)

# %% [markdown]
# <hr style="border:1px solid black"> </hr>
# <h3>Ans 2 - Age 50 to 60 has more chances of getting a Heart Attack.
# <hr style="border:1px solid black"> </hr>

# %% [markdown]
# ## Q3 - Which Chest Pain Type is most Dangerous ?

# %%
data['Cholesterol'] = data['Cholesterol'].apply(lambda x:data['Cholesterol'].median() if x==0 else x)

# %%
px.histogram(data_frame=data, x='Cholesterol', y='ChestPainType', color='Sex', height=480, width=800,
            color_discrete_map={'F':'red', 'M':'#42a5f5'},
            title='Cholestrol level and Chest Pain Type')

# %% [markdown]
# ![](https://storage.googleapis.com/kagglesdsdata/datasets/1821434/2971219/newplot%20%283%29.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20211226%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20211226T114916Z&X-Goog-Expires=345599&X-Goog-SignedHeaders=host&X-Goog-Signature=...)

# %% [markdown]
# <hr style="border:1px solid black"> </hr>
# <h3> Ans 3 - <b>ASY</b> Chest Pain Type is most dangerous because this is responsible for most Heart Failures.
# <hr style="border:1px solid black"> </hr>

# %% [markdown]
# ## Q4 - What level of Cholesterol leads to Heart Problems ?

# %%
px.histogram(data_frame=df, x='Cholesterol', y='Sex', color='HeartDisease', height=400, width=800,
            title='Effect of Cholesterol Level on Heart')

# %% [markdown]
# ![](https://storage.googleapis.com/kagglesdsdata/datasets/1821434/2971219/newplot%20%284%29.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20211226%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20211226T114946Z&X-Goog-Expires=345599&X-Goog-SignedHeaders=host&X-Goog-Signature=...)

# %% [markdown]
# <hr style="border:1px solid black"> </hr>
# <h3>Ans 4 - From above analysis, it is clear that generally females have less Cholesterol Levels. And after crossing 60k choleesterol level leads to Heart Failures.
# <hr style="border:1px solid black"> </hr>

# %% [markdown]
# ## Q5 - What does Heart Rate implies for Heart Diseases.

# %%
px.scatter(data_frame=df, y='Age', x='MaxHR', color='HeartDisease', height=550, width=900,
          color_discrete_map={0:'blue', 1:'cyan'}, trendline="ols",
          title='Effect of Heart Rate and Age on Diseases')

# %% [markdown]
# ![](https://storage.googleapis.com/kagglesdsdata/datasets/1821434/2971219/newplot%20%285%29.png?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=databundle-worker-v2%40kaggle-161607.iam.gserviceaccount.com%2F20211226%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20211226T114709Z&X-Goog-Expires=345599&X-Goog-SignedHeaders=host&X-Goog-Signature=...)

# %% [markdown]
# <hr style="border:1px solid black"> </hr>
# <h3>Ans 5 - People with HIGHER AGE GROUP having LOW HEART RATE are more prone to Heart Diseases.
# <hr style="border:1px solid black"> </hr>
